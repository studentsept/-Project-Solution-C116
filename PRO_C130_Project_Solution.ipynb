# %% [markdown]
# <a href="https://colab.research.google.com/github/studentsept/-Project-Solution-C116/blob/main/PRO_C130_Project_Solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATA CLEANING

# %%
# !git clone https://github.com/procodingclass/PRO-Stars-Dataset-CSVs
# Out:
# Cloning into 'PRO-Stars-Dataset-CSVs'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 21 (delta 7), reused 13 (delta 5), pack-reused 0
# Unpacking objects: 100% (21/21), done.

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/PRO-Stars-Dataset-CSVs/total_stars.csv')
df
# Out:
#      Unnamed: 0               Star_name     Distance                  Mass  \
# 0             0                     Sun  0.000015813                     1
# 1             1                  Sirius       0008.6                   2.1
# 2             2                 Canopus         0310                    15
# 3             3          Alpha Centauri       0004.4                   1.1
# 4             4                Arcturus         0037                   1.1
# ..          ...                     ...          ...                   ...
# 249         153  2MASSI J2356547-155310         74.0            0.07636704
# 250         154          WISE 0410+1502         20.0           0.005727528
# 251         155         WISE 0458+6434A         35.9  0.014318820000000001
# 252         156         WISE 0458+6434B         35.9            0.00954588
# 253         157          WISE 1405+5534         25.3  0.028637640000000002
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Star_name', 'Distance', 'Mass', 'Radius', 'Luminosity',
#        'Unnamed: 6', 'Star_name.1', 'Distance.1', 'Mass.1', 'Radius.1'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0','Unnamed: 6', 'Star_name.1', 'Distance.1', 'Mass.1', 'Radius.1','Luminosity'],axis=1,inplace=True)

# %%
df
# Out:
#                   Star_name     Distance                  Mass  \
# 0                       Sun  0.000015813                     1
# 1                    Sirius       0008.6                   2.1
# 2                   Canopus         0310                    15
# 3            Alpha Centauri       0004.4                   1.1
# 4                  Arcturus         0037                   1.1
# ..                      ...          ...                   ...
# 249  2MASSI J2356547-155310         74.0            0.07636704
# 250          WISE 0410+1502         20.0           0.005727528
# 251         WISE 0458+6434A         35.9  0.014318820000000001
# 252         WISE 0458+6434B         35.9            0.00954588
# 253          WISE 1405+5534         25.3  0.028637640000000002
#
#                   Radius
# 0                      1
# 1                  1.71´
# 2                     71
# 3                    1.2
# 4                     26
# ..                   ...
# ...

# %%
final_data = df.dropna()
final_data
# Out:
#                   Star_name     Distance                  Mass  \
# 0                       Sun  0.000015813                     1
# 1                    Sirius       0008.6                   2.1
# 2                   Canopus         0310                    15
# 3            Alpha Centauri       0004.4                   1.1
# 4                  Arcturus         0037                   1.1
# ..                      ...          ...                   ...
# 249  2MASSI J2356547-155310         74.0            0.07636704
# 250          WISE 0410+1502         20.0           0.005727528
# 251         WISE 0458+6434A         35.9  0.014318820000000001
# 252         WISE 0458+6434B         35.9            0.00954588
# 253          WISE 1405+5534         25.3  0.028637640000000002
#
#                   Radius
# 0                      1
# 1                  1.71´
# 2                     71
# 3                    1.2
# 4                     26
# ..                   ...
# ...

# %%
final_data.reset_index(drop=True,inplace = True)
final_data
# Out:
#                   Star_name     Distance                  Mass  \
# 0                       Sun  0.000015813                     1
# 1                    Sirius       0008.6                   2.1
# 2                   Canopus         0310                    15
# 3            Alpha Centauri       0004.4                   1.1
# 4                  Arcturus         0037                   1.1
# ..                      ...          ...                   ...
# 248  2MASSI J2356547-155310         74.0            0.07636704
# 249          WISE 0410+1502         20.0           0.005727528
# 250         WISE 0458+6434A         35.9  0.014318820000000001
# 251         WISE 0458+6434B         35.9            0.00954588
# 252          WISE 1405+5534         25.3  0.028637640000000002
#
#                   Radius
# 0                      1
# 1                  1.71´
# 2                     71
# 3                    1.2
# 4                     26
# ..                   ...
# ...

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Star_name  253 non-null    object
#  1   Distance   253 non-null    object
#  2   Mass       253 non-null    object
#  3   Radius     253 non-null    object
# dtypes: object(4)
# memory usage: 8.0+ KB

# %%
final_data.describe()
# Out:
#        Star_name Distance                  Mass               Radius
# count        253      253                   253                  253
# unique       253      199                   156                  144
# top          Sun     47.0  0.040092696000000004  0.09659721999999998
# freq           1        4                     7                   20

# %%
final_data.head(5)
# Out:
#         Star_name     Distance Mass Radius
# 0             Sun  0.000015813    1      1
# 1          Sirius       0008.6  2.1  1.71´
# 2         Canopus         0310   15     71
# 3  Alpha Centauri       0004.4  1.1    1.2
# 4        Arcturus         0037  1.1     26

# %%
final_data.dtypes
# Out:
# Star_name    object
# Distance     object
# Mass         object
# Radius       object
# dtype: object

# %%
final_data.to_csv('final_data.csv')

# %% [markdown]
# ## Download CSV

# %%
from google.colab import files
files.download("final_data.csv")
